# %%
# !git clone https://github.com/ntamotsu/Chat_with_character_using_stablediffusion.git
# !pip install -r /content/Chat_with_character_using_stablediffusion/requirements.txt

# %%
# !streamlit run /content/Chat_with_character_using_stablediffusion/app.py & sleep 3 && npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# 遷移先のページでExternal URLのIPを入力してsubmit
